# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Vaishali\DataScience\Python\PythonDemo1\Amazon Customer Behavior Survey.csv")

df
# Out:
#                           Timestamp  age             Gender  \
# 0    2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 1    2023/06/04 2:30:44 PM GMT+5:30   23             Female
# 2    2023/06/04 5:04:56 PM GMT+5:30   24  Prefer not to say
# 3    2023/06/04 5:13:00 PM GMT+5:30   24             Female
# 4    2023/06/04 5:28:06 PM GMT+5:30   22             Female
# ..                              ...  ...                ...
# 597  2023/06/12 4:02:02 PM GMT+5:30   23             Female
# 598  2023/06/12 4:02:53 PM GMT+5:30   23             Female
# 599  2023/06/12 4:03:59 PM GMT+5:30   23             Female
# 600  2023/06/12 9:57:20 PM GMT+5:30   23             Female
# 601  2023/06/16 9:16:05 AM GMT+5:30   23             Female
#
#          Purchase_Frequency  \
# 0         Few times a month
# 1              Once a month
# 2         Few times a month
# 3              Once a month
# 4    Less than once a month
# ..                      ...
# 597             Once a week
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'age', 'Gender', 'Purchase_Frequency',
#        'Purchase_Categories', 'Personalized_Recommendation_Frequency',
#        'Browsing_Frequency', 'Product_Search_Method',
#        'Search_Result_Exploration', 'Customer_Reviews_Importance',
#        'Add_to_Cart_Browsing', 'Cart_Completion_Frequency',
#        'Cart_Abandonment_Factors', 'Saveforlater_Frequency', 'Review_Left',
#        'Review_Reliability', 'Review_Helpfulness',
#        'Personalized_Recommendation_Frequency ', 'Recommendation_Helpfulness',
#        'Rating_Accuracy ', 'Shopping_Satisfaction', 'Service_Appreciation',
#        'Improvement_Areas'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Timestamp                               602 non-null    object
#  1   age                                     602 non-null    int64
#  2   Gender                                  602 non-null    object
#  3   Purchase_Frequency                      602 non-null    object
#  4   Purchase_Categories                     602 non-null    object
#  5   Personalized_Recommendation_Frequency   602 non-null    object
#  6   Browsing_Frequency                      602 non-null    object
#  7   Product_Search_Method                   600 non-null    object
#  8   Search_Result_Exploration               602 non-null    object
#  9   Customer_Reviews_Importance             602 non-null    int64
# ...

# %%
df.shape
# Out:
# (602, 23)

# %%
df.describe()
# Out:
#               age  Customer_Reviews_Importance  \
# count  602.000000                   602.000000
# mean    30.790698                     2.480066
# std     10.193276                     1.185226
# min      3.000000                     1.000000
# 25%     23.000000                     1.000000
# 50%     26.000000                     3.000000
# 75%     36.000000                     3.000000
# max     67.000000                     5.000000
#
#        Personalized_Recommendation_Frequency   Rating_Accuracy   \
# count                              602.000000        602.000000
# mean                                 2.699336          2.672757
# std                                  1.042028          0.899744
# min                                  1.000000          1.000000
# 25%                                  2.000000          2.000000
# 50%                                  3.000000          3.000000
# 75%                                  3.000000          3.000000
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                                 0
# age                                       0
# Gender                                    0
# Purchase_Frequency                        0
# Purchase_Categories                       0
# Personalized_Recommendation_Frequency     0
# Browsing_Frequency                        0
# Product_Search_Method                     0
# Search_Result_Exploration                 0
# Customer_Reviews_Importance               0
# Add_to_Cart_Browsing                      0
# Cart_Completion_Frequency                 0
# Cart_Abandonment_Factors                  0
# Saveforlater_Frequency                    0
# Review_Left                               0
# Review_Reliability                        0
# Review_Helpfulness                        0
# Personalized_Recommendation_Frequency     0
# Recommendation_Helpfulness                0
# Rating_Accuracy                           0
# Shopping_Satisfaction                     0
# ...

# %%
for i in df.columns:
    if(df[i].dtypes == 'object'):
        x = df[i].mode()[0]
        df[i] = df[i].fillna(x)
    else:
        x = df[i].mean()
        df[i] = df[i].fillna(x)

# %%
df.head()
# Out:
#                         Timestamp  age             Gender  \
# 0  2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 1  2023/06/04 2:30:44 PM GMT+5:30   23             Female
# 2  2023/06/04 5:04:56 PM GMT+5:30   24  Prefer not to say
# 3  2023/06/04 5:13:00 PM GMT+5:30   24             Female
# 4  2023/06/04 5:28:06 PM GMT+5:30   22             Female
#
#        Purchase_Frequency                                Purchase_Categories  \
# 0       Few times a month                           Beauty and Personal Care
# 1            Once a month                               Clothing and Fashion
# 2       Few times a month    Groceries and Gourmet Food;Clothing and Fashion
# 3            Once a month  Beauty and Personal Care;Clothing and Fashion;...
# 4  Less than once a month      Beauty and Personal Care;Clothing and Fashion
#
#   Personalized_Recommendation_Frequency Browsing_Frequency  \
# 0                                   Yes   Few times a week
# ...

# %%
df.tail()
# Out:
#                           Timestamp  age  Gender Purchase_Frequency  \
# 597  2023/06/12 4:02:02 PM GMT+5:30   23  Female        Once a week
# 598  2023/06/12 4:02:53 PM GMT+5:30   23  Female        Once a week
# 599  2023/06/12 4:03:59 PM GMT+5:30   23  Female       Once a month
# 600  2023/06/12 9:57:20 PM GMT+5:30   23  Female  Few times a month
# 601  2023/06/16 9:16:05 AM GMT+5:30   23  Female        Once a week
#
#                                    Purchase_Categories  \
# 597                           Beauty and Personal Care
# 598                               Clothing and Fashion
# 599                           Beauty and Personal Care
# 600  Beauty and Personal Care;Clothing and Fashion;...
# 601                               Clothing and Fashion
#
#     Personalized_Recommendation_Frequency    Browsing_Frequency  \
# 597                             Sometimes      Few times a week
# 598                             Sometimes      Few times a week
# ...

# %%
df['Purchase_Categories'].value_counts()
# Out:
# Purchase_Categories
# Beauty and Personal Care                                                                            106
# Clothing and Fashion                                                                                106
# others                                                                                               48
# Beauty and Personal Care;Clothing and Fashion                                                        46
# Beauty and Personal Care;Clothing and Fashion;Home and Kitchen                                       42
# Groceries and Gourmet Food;Beauty and Personal Care;Clothing and Fashion;Home and Kitchen;others     32
# Clothing and Fashion;Home and Kitchen                                                                27
# Home and Kitchen                                                                                     24
# Beauty and Personal Care;Home and Kitchen                                                            21
# ...

# %%
df['Purchase_Categories'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                               Beauty and Personal Care
# 1                                   Clothing and Fashion
# 2        Groceries and Gourmet Food;Clothing and Fashion
# 3      Beauty and Personal Care;Clothing and Fashion;...
# 4          Beauty and Personal Care;Clothing and Fashion
#                              ...
# 597                             Beauty and Personal Care
# 598                                 Clothing and Fashion
# 599                             Beauty and Personal Care
# 600    Beauty and Personal Care;Clothing and Fashion;...
# 601                                 Clothing and Fashion
# Name: Purchase_Categories, Length: 602, dtype: object>

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 597    False
# 598    False
# 599    False
# 600    False
# 601    False
# Length: 602, dtype: bool

# %%
df.agg(['sum'])
# Out:
#                                              Timestamp    age  \
# sum  2023/06/04 1:28:19 PM GMT+5:302023/06/04 2:30:...  18536
#
#                                                 Gender  \
# sum  FemaleFemalePrefer not to sayFemaleFemaleFemal...
#
#                                     Purchase_Frequency  \
# sum  Few times a monthOnce a monthFew times a month...
#
#                                    Purchase_Categories  \
# sum  Beauty and Personal CareClothing and FashionGr...
#
#                  Personalized_Recommendation_Frequency  \
# sum  YesYesNoSometimesYesNoNoNoSometimesNoNoNoNoNoY...
#
#                                     Browsing_Frequency  \
# sum  Few times a weekFew times a monthFew times a m...
#
#                                  Product_Search_Method  \
# sum  KeywordKeywordKeywordKeywordFiltercategoriesFi...
#
#                              Search_Result_Exploration  \
# sum  Multiple pagesMultiple pagesMultiple pagesFirs...
#
# ...

# %%
df.sort_values(by='Purchase_Frequency')
# Out:
#                            Timestamp  age             Gender  \
# 0     2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 357   2023/06/08 5:33:01 PM GMT+5:30   40  Prefer not to say
# 352   2023/06/08 5:30:12 PM GMT+5:30   28  Prefer not to say
# 345   2023/06/08 5:24:42 PM GMT+5:30   34             Others
# 344   2023/06/08 5:23:08 PM GMT+5:30   37  Prefer not to say
# ..                               ...  ...                ...
# 418  2023/06/08 10:41:11 PM GMT+5:30   23             Female
# 421   2023/06/09 9:31:57 AM GMT+5:30   21             Female
# 424   2023/06/09 9:34:07 AM GMT+5:30   21             Female
# 396   2023/06/08 6:00:06 PM GMT+5:30   32             Female
# 601   2023/06/16 9:16:05 AM GMT+5:30   23             Female
#
#     Purchase_Frequency                                Purchase_Categories  \
# 0    Few times a month                           Beauty and Personal Care
# 357  Few times a month    Groceries and Gourmet Food;Clothing and Fashion
# ...

# %%
df.agg(['min','max'])
# Out:
#                            Timestamp  age             Gender  \
# min  2023/06/04 10:13:28 PM GMT+5:30    3             Female
# max   2023/06/16 9:16:05 AM GMT+5:30   67  Prefer not to say
#
#     Purchase_Frequency       Purchase_Categories  \
# min  Few times a month  Beauty and Personal Care
# max        Once a week                    others
#
#     Personalized_Recommendation_Frequency Browsing_Frequency  \
# min                                    No  Few times a month
# max                                   Yes             Rarely
#
#     Product_Search_Method Search_Result_Exploration  \
# min                Filter                First page
# max                others            Multiple pages
#
#      Customer_Reviews_Importance  ... Saveforlater_Frequency Review_Left  \
# min                            1  ...                 Always          No
# max                            5  ...              Sometimes         Yes
#
#     Review_Reliability Review_Helpfulness  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'age', 'Gender', 'Purchase_Frequency',
#        'Purchase_Categories', 'Personalized_Recommendation_Frequency',
#        'Browsing_Frequency', 'Product_Search_Method',
#        'Search_Result_Exploration', 'Customer_Reviews_Importance',
#        'Add_to_Cart_Browsing', 'Cart_Completion_Frequency',
#        'Cart_Abandonment_Factors', 'Saveforlater_Frequency', 'Review_Left',
#        'Review_Reliability', 'Review_Helpfulness',
#        'Personalized_Recommendation_Frequency ', 'Recommendation_Helpfulness',
#        'Rating_Accuracy ', 'Shopping_Satisfaction', 'Service_Appreciation',
#        'Improvement_Areas'],
#       dtype='object')

# %%
df.groupby(by = 'Product_Search_Method').count()
# Out:
#                        Timestamp  age  Gender  Purchase_Frequency  \
# Product_Search_Method
# Filter                       127  127     127                 127
# Keyword                      214  214     214                 214
# categories                   225  225     225                 225
# others                        36   36      36                  36
#
#                        Purchase_Categories  \
# Product_Search_Method
# Filter                                 127
# Keyword                                214
# categories                             225
# others                                  36
#
#                        Personalized_Recommendation_Frequency  \
# Product_Search_Method
# Filter                                                   127
# Keyword                                                  214
# categories                                               225
# others                                                    36
#
# ...

# %%
df.iloc[5:10,[2,4]]
# Out:
#    Gender                            Purchase_Categories
# 5  Female                           Clothing and Fashion
# 6  Female                           Clothing and Fashion
# 7  Female  Beauty and Personal Care;Clothing and Fashion
# 8  Female  Beauty and Personal Care;Clothing and Fashion
# 9  Female  Beauty and Personal Care;Clothing and Fashion

# %%
df.loc[5:10]
# Out:
#                          Timestamp  age  Gender      Purchase_Frequency  \
# 5   2023/06/04 6:01:59 PM GMT+5:30   21  Female  Less than once a month
# 6   2023/06/04 6:31:41 PM GMT+5:30   22  Female  Less than once a month
# 7   2023/06/04 7:13:12 PM GMT+5:30   21  Female       Few times a month
# 8   2023/06/04 7:23:21 PM GMT+5:30   20  Female  Less than once a month
# 9   2023/06/04 7:33:12 PM GMT+5:30   23  Female  Less than once a month
# 10  2023/06/04 7:45:33 PM GMT+5:30   22  Female  Less than once a month
#
#                               Purchase_Categories  \
# 5                            Clothing and Fashion
# 6                            Clothing and Fashion
# 7   Beauty and Personal Care;Clothing and Fashion
# 8   Beauty and Personal Care;Clothing and Fashion
# 9   Beauty and Personal Care;Clothing and Fashion
# 10                           Clothing and Fashion
#
#    Personalized_Recommendation_Frequency Browsing_Frequency  \
# ...

# %%
df.sort_values(by=['Timestamp'])
# Out:
#                            Timestamp  age  Gender      Purchase_Frequency  \
# 30   2023/06/04 10:13:28 PM GMT+5:30   25  Female       Few times a month
# 31   2023/06/04 10:24:47 PM GMT+5:30   23  Female  Less than once a month
# 32   2023/06/04 10:37:00 PM GMT+5:30   23  Female  Less than once a month
# 33   2023/06/04 11:09:27 PM GMT+5:30   23  Female  Less than once a month
# 34   2023/06/04 11:12:15 PM GMT+5:30   23    Male   Multiple times a week
# ..                               ...  ...     ...                     ...
# 598   2023/06/12 4:02:53 PM GMT+5:30   23  Female             Once a week
# 599   2023/06/12 4:03:59 PM GMT+5:30   23  Female            Once a month
# 565   2023/06/12 9:40:22 AM GMT+5:30   34  Female             Once a week
# 600   2023/06/12 9:57:20 PM GMT+5:30   23  Female       Few times a month
# 601   2023/06/16 9:16:05 AM GMT+5:30   23  Female             Once a week
#
#                                    Purchase_Categories  \
# ...

# %%
df['Product_Search_Method'].value_counts().plot(kind='bar',title='Count plot for keyword',xlabel='Product_Search_Method',ylabel='count')
# Out:
# <Axes: title={'center': 'Count plot for keyword'}, xlabel='Product_Search_Method', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

sns.histplot(data=df,x=df['age'],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.scatter(df['Rating_Accuracy '],df['age'])

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='age')

# %%
import seaborn as sns

sns.boxplot(x=df['Rating_Accuracy '],y=df['Customer_Reviews_Importance'])
# Out:
# <Axes: xlabel='Rating_Accuracy ', ylabel='Customer_Reviews_Importance'>
